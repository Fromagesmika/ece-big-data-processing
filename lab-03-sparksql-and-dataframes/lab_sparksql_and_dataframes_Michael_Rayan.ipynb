# %% [markdown]
# # Exploratory Data Analysis with Pyspark and Spark SQL
#
# The following notebook utilizes New York City taxi data from [TLC Trip Record Data](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page)
#
# ## Instructions
#
# - Load and explore nyc taxi data from january 0f 2019. The exercises can be executed using pyspark or spark sql (a subset of the questions will be re-answered using the language not chosen for the  main work).
# - Load the zone lookup table to answer the questions about the nyc boroughs.
# - Load nyc taxi data from January of 2025 and compare data.
# - With any remaining time, work on the where to go from here section.
# - Note: the initial lab is opened as read only. To save work completed utilize the `save notebook as` option and give the lab a new name.

# %%
import requests

# start a spark session and create a spark context
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("nyc_taxi") \
    .getOrCreate()

sc = spark.sparkContext

# %%
# set dl url for January 2019 trip data
download_url = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet'

# get the data
response = requests.get(download_url)

# check that response was good and save the data
jan_2019_trip_data = "yellow_tripdata_2019-01.parquet"
if response.status_code == 200:
    # Changed 'response' to 'data' here
    with open(jan_2019_trip_data, "wb") as f:
        f.write(response.content)

# %%
# create the dataframe
df_trips = spark.read.parquet(jan_2019_trip_data)

# %% [markdown]
# # A brief note on handling data sources in spark
#
# The command above works well for loading data from parquet files because parquet is a self descibing file format, meaning that the metadata needed to build the dataframe is included directly in the format. However, when working with other formats such as csv or json, a schema must be provided or infered. In production code the schema should always be explicitly provided but during the data exploration phase it is acceptable to infer the schema, and when infering the schema it often best to use `.option("samplingRatio", <small-portion-of-data>)` to avoid using the entire dataset for schema inference.
#
# ```python
# df_trips = spark.read.format("csv") \
#     .option("header", "true") \
#     .option("sep", ",") \
#     .option("samplingRatio", 0.01) \
#     .load("large_dataset.csv")
# ```

# %%
# Show the dataframe
df_trips.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|            1.0|          1.5|       1.0|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                NULL|       NULL|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|            1.0|          2.6|       1.0|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                NULL|       NULL|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|       1.0|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|       NULL|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|       NULL|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|
# |       2| 2018-11-28 16:25:49|  2018-11-28 16:28:26|            5.0|          0.0|       1.0|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|        5.76|                  0.3|       13.31|                NULL|       NULL|
# |       2| 2018-11-28 16:29:37|  2018-11-28 16:33:43|            5.0|          0.0|       2.0|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|       NULL|
# |       1| 2019-01-01 00:21:28|  2019-01-01 00:28:37|            1.0|          1.3|       1.0|                 N|         163|         229|           1|        6.5|  0.5|    0.5|      1.25|         0.0|                  0.3|        9.05|                NULL|       NULL|
# |       1| 2019-01-01 00:32:01|  2019-01-01 00:45:39|            1.0|          3.7|       1.0|                 N|         229|           7|           1|       13.5|  0.5|    0.5|       3.7|         0.0|                  0.3|        18.5|                NULL|       NULL|
# |       1| 2019-01-01 00:57:32|  2019-01-01 01:09:32|            2.0|          2.1|       1.0|                 N|         141|         234|           1|       10.0|  0.5|    0.5|       1.7|         0.0|                  0.3|        13.0|                NULL|       NULL|
# |       1| 2019-01-01 00:24:04|  2019-01-01 00:47:06|            2.0|          2.8|       1.0|                 N|         246|         162|           1|       15.0|  0.5|    0.5|      3.25|         0.0|                  0.3|       19.55|                NULL|       NULL|
# |       1| 2019-01-01 00:21:59|  2019-01-01 00:28:24|            1.0|          0.7|       1.0|                 N|         238|         151|           1|        5.5|  0.5|    0.5|       1.7|         0.0|                  0.3|         8.5|                NULL|       NULL|
# |       1| 2019-01-01 00:45:21|  2019-01-01 01:31:05|            1.0|          8.7|       1.0|                 N|         163|          25|           1|       34.5|  0.5|    0.5|      7.15|         0.0|                  0.3|       42.95|                NULL|       NULL|
# |       1| 2019-01-01 00:43:19|  2019-01-01 01:07:42|            1.0|          6.3|       1.0|                 N|         224|          25|           1|       21.5|  0.5|    0.5|       5.7|         0.0|                  0.3|        28.5|                NULL|       NULL|
# |       1| 2019-01-01 00:58:24|  2019-01-01 01:15:18|            1.0|          2.7|       1.0|                 N|         141|         234|           1|       13.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        15.3|                NULL|       NULL|
# |       2| 2019-01-01 00:23:14|  2019-01-01 00:25:40|            1.0|         0.38|       1.0|                 N|         170|         170|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         4.8|                NULL|       NULL|
# |       2| 2019-01-01 00:39:51|  2019-01-01 00:48:02|            1.0|         0.55|       1.0|                 N|         170|         170|           1|        6.5|  0.5|    0.5|      1.95|         0.0|                  0.3|        9.75|                NULL|       NULL|
# |       2| 2019-01-01 00:46:00|  2019-01-01 00:49:07|            1.0|          0.3|       1.0|                 N|         107|         107|           1|        4.0|  0.5|    0.5|      1.06|         0.0|                  0.3|        6.36|                NULL|       NULL|
# |       2| 2019-01-01 00:57:45|  2019-01-01 01:03:51|            1.0|         1.42|       1.0|                 N|         170|         141|           1|        6.5|  0.5|    0.5|      1.56|         0.0|                  0.3|        9.36|                NULL|       NULL|
# |       2| 2019-01-01 00:16:16|  2019-01-01 00:25:57|            1.0|         1.72|       1.0|                 N|          41|         247|           2|        9.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        10.3|                NULL|       NULL|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
df_trips.printSchema()
print("Number of rows:", df_trips.count())
print("Number of columns:", len(df_trips.columns))
df_trips.columns
# Out:
# root
#  |-- VendorID: long (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: double (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: double (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: integer (nullable = true)
#
# Number of rows: 7696617
# Number of columns: 19
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'airport_fee']

# %% [markdown]
# ## Lab
#
# ### Part 1
# This section can be completed either using pyspark commands or sql commands ( There will be a section after in which a self-chosen subset of the questions are re-answered using the language not used for the main section. i.e. if pyspark is chosen for the main lab, sql should be used to repeat some of the questions. )
#
# - 1) Add a column that creates a unique key to identify each record in order to answer questions about individual trips
# - 2) Which trip has the highest passanger count
# - 3) What is the Average passanger count
# - 4) Shortest/longest trip by distance? by time?.
# - 5) busiest day/slowest single day
# - 6) busiest/slowest time of day ( you may want to bucket these by hour or create timess such as morning, afternoon, evening, late night )
# - 7) On average which day of the week is slowest/busiest
# - 8) Does trip distance or num passangers affect tip amount
# - 9) What was the highest "extra" charge and which trip
# - 10) Are there any datapoints that seem to be strange/outliers (make sure to explain your reasoning in a markdown cell)?

# %% [markdown]
# **1)**

# %%
from pyspark.sql import functions as F
df_trips = df_trips.withColumn(
    "trip_id",
    F.monotonically_increasing_id()
)
df_trips.select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "passenger_count",
    "trip_distance"
).show(10)
# Out:
# +-----------+--------------------+---------------------+---------------+-------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|
# +-----------+--------------------+---------------------+---------------+-------------+
# |25769803776| 2019-01-01 00:46:40|  2019-01-01 00:53:20|            1.0|          1.5|
# |25769803777| 2019-01-01 00:59:47|  2019-01-01 01:18:59|            1.0|          2.6|
# |25769803778| 2018-12-21 13:48:30|  2018-12-21 13:52:40|            3.0|          0.0|
# |25769803779| 2018-11-28 15:52:25|  2018-11-28 15:55:45|            5.0|          0.0|
# |25769803780| 2018-11-28 15:56:57|  2018-11-28 15:58:33|            5.0|          0.0|
# |25769803781| 2018-11-28 16:25:49|  2018-11-28 16:28:26|            5.0|          0.0|
# |25769803782| 2018-11-28 16:29:37|  2018-11-28 16:33:43|            5.0|          0.0|
# |25769803783| 2019-01-01 00:21:28|  2019-01-01 00:28:37|            1.0|          1.3|
# |25769803784| 2019-01-01 00:32:01|  2019-01-01 00:45:39|            1.0|          3.7|
# |25769803785| 2019-01-01 00:57:32|  2019-01-01 01:09:32|            2.0|          2.1|
# +-----------+--------------------+---------------------+---------------+-------------+
# only showing top 10 rows

# %% [markdown]
# **2)**

# %%
df_trips.orderBy(
    F.col("passenger_count").desc()
).select(
    "trip_id",
    "passenger_count",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance"
).show(10)

df_trips.select(
    F.max("passenger_count").alias("max_passenger_count")
).show()
# Out:
# +-----------+---------------+--------------------+---------------------+-------------+
# |    trip_id|passenger_count|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|
# +-----------+---------------+--------------------+---------------------+-------------+
# |25770753732|            9.0| 2019-01-05 13:12:29|  2019-01-05 13:12:32|          0.0|
# |25772687771|            9.0| 2019-01-13 04:13:24|  2019-01-13 04:14:34|          0.0|
# |25771100063|            9.0| 2019-01-07 03:19:36|  2019-01-07 03:20:01|          0.0|
# |25771815874|            9.0| 2019-01-10 00:43:10|  2019-01-10 00:43:14|          0.0|
# |25774338483|            9.0| 2019-01-19 16:45:25|  2019-01-19 16:45:27|          0.0|
# |25774656001|            9.0| 2019-01-21 03:46:51|  2019-01-21 03:46:56|          0.0|
# |25774801566|            9.0| 2019-01-21 19:20:28|  2019-01-21 19:20:31|          0.0|
# |25777090459|            9.0| 2019-01-30 18:34:12|  2019-01-30 18:34:16|          0.0|
# |25777177652|            9.0| 2019-01-30 22:17:51|  2019-01-30 22:44:53|        13.38|
# |25771413061|            8.0| 2019-01-08 12:22:01|  2019-01-08 12:22:05|          0.0|
# +-----------+---------------+--------------------+---------------------+-------------+
# only showing top 10 rows
# +-------------------+
# |max_passenger_count|
# +-------------------+
# |                9.0|
# +-------------------+

# %% [markdown]
# **3)**

# %%
df_trips.select(
    F.avg("passenger_count").alias("AVG Passenger Count")
).show()
# Out:
# +-------------------+
# |AVG Passenger Count|
# +-------------------+
# | 1.5670317144945614|
# +-------------------+

# %% [markdown]
# **4)**

# %% [markdown]
# ## Distance

# %% [markdown]
# ### Shortest

# %%
df_trips.orderBy(
    F.col("trip_distance").desc()
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance"
).show(1)
# Out:
# +-----------+--------------------+---------------------+-------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|
# +-----------+--------------------+---------------------+-------------+
# |25775877867| 2019-01-25 21:56:39|  2019-01-25 22:06:08|        831.8|
# +-----------+--------------------+---------------------+-------------+
# only showing top 1 row

# %% [markdown]
# ### Longest

# %%
df_trips.orderBy(
    F.col("trip_distance").asc()
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance"
).show(1)
# Out:
# +-----------+--------------------+---------------------+-------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|
# +-----------+--------------------+---------------------+-------------+
# |25769803778| 2018-12-21 13:48:30|  2018-12-21 13:52:40|          0.0|
# +-----------+--------------------+---------------------+-------------+
# only showing top 1 row

# %% [markdown]
# ## Time

# %%
df_trips = df_trips.withColumn(
    "trip_duration_seconds",
    F.unix_timestamp("tpep_dropoff_datetime")
    - F.unix_timestamp("tpep_pickup_datetime")
)

# %%
df_trips = df_trips.withColumn(
    "trip_duration_minutes",
    F.col("trip_duration_seconds") / 60
)

# %%
df_trips.select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_duration_minutes"
).show(10)
# Out:
# +-----------+--------------------+---------------------+---------------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_duration_minutes|
# +-----------+--------------------+---------------------+---------------------+
# |25769803776| 2019-01-01 00:46:40|  2019-01-01 00:53:20|    6.666666666666667|
# |25769803777| 2019-01-01 00:59:47|  2019-01-01 01:18:59|                 19.2|
# |25769803778| 2018-12-21 13:48:30|  2018-12-21 13:52:40|    4.166666666666667|
# |25769803779| 2018-11-28 15:52:25|  2018-11-28 15:55:45|   3.3333333333333335|
# |25769803780| 2018-11-28 15:56:57|  2018-11-28 15:58:33|                  1.6|
# |25769803781| 2018-11-28 16:25:49|  2018-11-28 16:28:26|   2.6166666666666667|
# |25769803782| 2018-11-28 16:29:37|  2018-11-28 16:33:43|                  4.1|
# |25769803783| 2019-01-01 00:21:28|  2019-01-01 00:28:37|                 7.15|
# |25769803784| 2019-01-01 00:32:01|  2019-01-01 00:45:39|   13.633333333333333|
# |25769803785| 2019-01-01 00:57:32|  2019-01-01 01:09:32|                 12.0|
# +-----------+--------------------+---------------------+---------------------+
# only showing top 10 rows

# %% [markdown]
# ### Shortest

# %%
df_trips.orderBy(
    F.col("trip_duration_seconds").asc()
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance",
    "trip_duration_seconds",
    "trip_duration_minutes"
).show(1)
# Out:
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|trip_duration_seconds|trip_duration_minutes|
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# |25771006960| 2019-01-06 15:15:08|  2018-11-09 02:34:38|          3.3|             -5056830|             -84280.5|
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# only showing top 1 row

# %% [markdown]
# ### Longest

# %%
df_trips.orderBy(
    F.col("trip_duration_seconds").desc()
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance",
    "trip_duration_seconds",
    "trip_duration_minutes"
).show(1)
# Out:
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|trip_duration_seconds|trip_duration_minutes|
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# |25769872043| 2019-01-01 07:01:20|  2019-01-31 14:29:21|          1.2|              2618881|    43648.01666666667|
# +-----------+--------------------+---------------------+-------------+---------------------+---------------------+
# only showing top 1 row

# %% [markdown]
# **5)**

# %%
df_trips = df_trips.withColumn(
    "pickup_date",
    F.to_date("tpep_pickup_datetime")
)
df_trips.select(
    "tpep_pickup_datetime",
    "pickup_date"
).show(10)
# Out:
# +--------------------+-----------+
# |tpep_pickup_datetime|pickup_date|
# +--------------------+-----------+
# | 2019-01-01 00:46:40| 2019-01-01|
# | 2019-01-01 00:59:47| 2019-01-01|
# | 2018-12-21 13:48:30| 2018-12-21|
# | 2018-11-28 15:52:25| 2018-11-28|
# | 2018-11-28 15:56:57| 2018-11-28|
# | 2018-11-28 16:25:49| 2018-11-28|
# | 2018-11-28 16:29:37| 2018-11-28|
# | 2019-01-01 00:21:28| 2019-01-01|
# | 2019-01-01 00:32:01| 2019-01-01|
# | 2019-01-01 00:57:32| 2019-01-01|
# +--------------------+-----------+
# only showing top 10 rows

# %%
df_jan = df_trips.filter(
    (F.col("pickup_date") >= "2019-01-01") &
    (F.col("pickup_date") <= "2019-01-31")
)
df_jan.select(
    F.min("pickup_date").alias("first_date"),
    F.max("pickup_date").alias("last_date")
).show()
# Out:
# +----------+----------+
# |first_date| last_date|
# +----------+----------+
# |2019-01-01|2019-01-31|
# +----------+----------+

# %%
trips_per_day = (
    df_jan
    .groupBy("pickup_date")
    .count()
)
trips_per_day.orderBy("pickup_date").show(31)
# Out:
# +-----------+------+
# |pickup_date| count|
# +-----------+------+
# | 2019-01-01|189432|
# | 2019-01-02|198737|
# | 2019-01-03|223965|
# | 2019-01-04|236089|
# | 2019-01-05|236506|
# | 2019-01-06|208823|
# | 2019-01-07|228816|
# | 2019-01-08|237310|
# | 2019-01-09|255868|
# | 2019-01-10|281863|
# | 2019-01-11|291714|
# | 2019-01-12|265115|
# | 2019-01-13|227502|
# | 2019-01-14|245082|
# | 2019-01-15|267370|
# | 2019-01-16|272699|
# | 2019-01-17|284580|
# | 2019-01-18|266848|
# | 2019-01-19|236365|
# | 2019-01-20|203114|
# | 2019-01-21|192826|
# | 2019-01-22|255178|
# | 2019-01-23|261151|
# | 2019-01-24|281959|
# | 2019-01-25|292499|
# | 2019-01-26|271993|
# | 2019-01-27|220451|
# | 2019-01-28|241040|
# | 2019-01-29|259786|
# | 2019-01-30|276774|
# | 2019-01-31|284625|
# +-----------+------+

# %%
trips_per_day = trips_per_day.withColumn(
    "day_name",
    F.date_format("pickup_date", "EEEE")
)

# %% [markdown]
# ### Busiest day

# %%
trips_per_day.orderBy(
    F.col("count").desc()
).show(5)
# Out:
# +-----------+------+--------+
# |pickup_date| count|day_name|
# +-----------+------+--------+
# | 2019-01-25|292499|  Friday|
# | 2019-01-11|291714|  Friday|
# | 2019-01-31|284625|Thursday|
# | 2019-01-17|284580|Thursday|
# | 2019-01-24|281959|Thursday|
# +-----------+------+--------+
# only showing top 5 rows

# %% [markdown]
# ### Slowest day

# %%
trips_per_day.orderBy(
    F.col("count").asc()
).show(5)
# Out:
# +-----------+------+---------+
# |pickup_date| count| day_name|
# +-----------+------+---------+
# | 2019-01-01|189432|  Tuesday|
# | 2019-01-21|192826|   Monday|
# | 2019-01-02|198737|Wednesday|
# | 2019-01-20|203114|   Sunday|
# | 2019-01-06|208823|   Sunday|
# +-----------+------+---------+
# only showing top 5 rows

# %% [markdown]
# **6)**

# %%
df_jan = df_jan.withColumn(
    "pickup_hour",
    F.hour("tpep_pickup_datetime")
)
df_jan.select(
    "tpep_pickup_datetime",
    "pickup_hour"
).show(10)
# Out:
# +--------------------+-----------+
# |tpep_pickup_datetime|pickup_hour|
# +--------------------+-----------+
# | 2019-01-01 00:46:40|          0|
# | 2019-01-01 00:59:47|          0|
# | 2019-01-01 00:21:28|          0|
# | 2019-01-01 00:32:01|          0|
# | 2019-01-01 00:57:32|          0|
# | 2019-01-01 00:24:04|          0|
# | 2019-01-01 00:21:59|          0|
# | 2019-01-01 00:45:21|          0|
# | 2019-01-01 00:43:19|          0|
# | 2019-01-01 00:58:24|          0|
# +--------------------+-----------+
# only showing top 10 rows

# %%
trips_per_hour = (
    df_jan
    .groupBy("pickup_hour")
    .count()
)
trips_per_hour.orderBy(
    "pickup_hour"
).show(24)
# Out:
# +-----------+------+
# |pickup_hour| count|
# +-----------+------+
# |          0|207758|
# |          1|149242|
# |          2|109413|
# |          3| 78084|
# |          4| 61423|
# |          5| 75532|
# |          6|178598|
# |          7|304858|
# |          8|373735|
# |          9|365924|
# |         10|361382|
# |         11|375438|
# |         12|401172|
# |         13|404149|
# |         14|433115|
# |         15|452679|
# |         16|420806|
# |         17|468407|
# |         18|515374|
# |         19|475152|
# |         20|423128|
# |         21|409873|
# |         22|369026|
# |         23|281812|
# +-----------+------+

# %% [markdown]
# ### Busiest time of day

# %%
trips_per_hour.orderBy(
    F.col("count").desc()
).show(5)
# Out:
# +-----------+------+
# |pickup_hour| count|
# +-----------+------+
# |         18|515374|
# |         19|475152|
# |         17|468407|
# |         15|452679|
# |         14|433115|
# +-----------+------+
# only showing top 5 rows

# %% [markdown]
# ### Slowest time of day

# %%
trips_per_hour.orderBy(
    F.col("count").asc()
).show(5)
# Out:
# +-----------+------+
# |pickup_hour| count|
# +-----------+------+
# |          4| 61423|
# |          5| 75532|
# |          3| 78084|
# |          2|109413|
# |          1|149242|
# +-----------+------+
# only showing top 5 rows

# %% [markdown]
# **7)**

# %%
avg_trips_by_weekday = (
    trips_per_day
    .groupBy("day_name")
    .agg(
        F.avg("count").alias("avg_trips")
    )
)
avg_trips_by_weekday.orderBy(
    F.col("avg_trips").desc()
).show()
# Out:
# +---------+---------+
# | day_name|avg_trips|
# +---------+---------+
# |   Friday| 271787.5|
# | Thursday| 271398.4|
# |Wednesday| 253045.8|
# | Saturday|252494.75|
# |  Tuesday| 241815.2|
# |   Monday| 226941.0|
# |   Sunday| 214972.5|
# +---------+---------+

# %% [markdown]
# ### Busiest day of week on average

# %%
avg_trips_by_weekday.orderBy(
    F.col("avg_trips").desc()
).show(1)
# Out:
# +--------+---------+
# |day_name|avg_trips|
# +--------+---------+
# |  Friday| 271787.5|
# +--------+---------+
# only showing top 1 row

# %% [markdown]
# ### Slowest day of week on average

# %%
avg_trips_by_weekday.orderBy(
    F.col("avg_trips").asc()
).show(1)
# Out:
# +--------+---------+
# |day_name|avg_trips|
# +--------+---------+
# |  Sunday| 214972.5|
# +--------+---------+
# only showing top 1 row

# %% [markdown]
# **8)**

# %% [markdown]
# ### Distance vs Tip amount

# %%
distance_tip_corr = df_jan.stat.corr(
    "trip_distance",
    "tip_amount"
)

print("Correlation between trip distance and tip amount:", distance_tip_corr)
# Out:
# Correlation between trip distance and tip amount: 0.5269460290274736

# %%
df_distance = df_jan.withColumn(
    "distance_group",
    F.when(F.col("trip_distance") < 1, "0-1 miles")
     .when(F.col("trip_distance") < 2, "1-2 miles")
     .when(F.col("trip_distance") < 5, "2-5 miles")
     .when(F.col("trip_distance") < 10, "5-10 miles")
     .otherwise("10+ miles")
)

# %%
distance_tip_analysis = (
    df_distance
    .groupBy("distance_group")
    .agg(
        F.avg("tip_amount").alias("avg_tip"),
        F.count("*").alias("trip_count")
    )
)
distance_tip_analysis.show()
# Out:
# +--------------+------------------+----------+
# |distance_group|           avg_tip|trip_count|
# +--------------+------------------+----------+
# |    5-10 miles|3.4700431561346394|    585780|
# |     2-5 miles|1.9824307604593454|   1918918|
# |     1-2 miles|1.3091200129885057|   2617675|
# |     0-1 miles|0.9403490888599677|   2132437|
# |     10+ miles| 6.219591066692631|    441270|
# +--------------+------------------+----------+

# %% [markdown]
# ### Passenger vs Tip amount

# %%
passenger_tip_analysis = (
    df_jan
    .groupBy("passenger_count")
    .agg(
        F.avg("tip_amount").alias("avg_tip"),
        F.count("*").alias("trip_count")
    )
    .orderBy("passenger_count")
)
passenger_tip_analysis.show()
# Out:
# +---------------+--------------------+----------+
# |passenger_count|             avg_tip|trip_count|
# +---------------+--------------------+----------+
# |           NULL|0.061789899553571406|     28672|
# |            0.0|  1.7869007761051638|    117381|
# |            1.0|  1.8283797977982486|   5456177|
# |            2.0|  1.8339551479007163|   1113794|
# |            3.0|  1.7956389567716011|    314677|
# |            4.0|  1.7023888221793764|    140743|
# |            5.0|  1.8699418452025662|    323791|
# |            6.0|  1.8567878060442715|    200788|
# |            7.0|   6.542631578947368|        19|
# |            8.0|   6.480689655172414|        29|
# |            9.0|  3.1166666666666667|         9|
# +---------------+--------------------+----------+

# %%
passenger_tip_corr = df_jan.stat.corr(
    "passenger_count",
    "tip_amount"
)

print(
    "Correlation between passenger count and tip amount:",
    passenger_tip_corr
)
# Out:
# Correlation between passenger count and tip amount: 0.004426230205403716

# %% [markdown]
# **9)**

# %%
df_jan.orderBy(
    F.col("extra").desc()
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance",
    "passenger_count",
    "fare_amount",
    "extra",
    "total_amount"
).show(10)
# Out:
# +-----------+--------------------+---------------------+-------------+---------------+-----------+------+------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|passenger_count|fare_amount| extra|total_amount|
# +-----------+--------------------+---------------------+-------------+---------------+-----------+------+------------+
# |25775127259| 2019-01-23 08:58:09|  2019-01-23 08:58:09|          0.0|            1.0|  355676.98|535.38|   356214.78|
# |25777257006| 2019-01-31 10:06:09|  2019-01-31 10:06:09|          0.0|            1.0|        4.5| 23.04|       28.34|
# |25770346979| 2019-01-03 18:32:36|  2019-01-03 19:45:29|         16.6|            1.0|       61.0|  18.5|        92.3|
# |25770114828| 2019-01-02 16:33:28|  2019-01-02 17:17:08|        17.23|            1.0|       52.0|  18.5|        88.3|
# |25770352084| 2019-01-03 18:19:33|  2019-01-03 18:55:54|        16.74|            1.0|       47.5|  18.5|       94.56|
# |25772258862| 2019-01-11 16:08:48|  2019-01-11 16:58:11|        15.78|            1.0|       49.0|  18.5|       96.36|
# |25773820911| 2019-01-17 16:24:12|  2019-01-17 17:29:50|        34.39|            1.0|       91.5|  18.5|      134.32|
# |25769938325| 2019-01-01 16:09:32|  2019-01-01 16:47:57|         13.4|            1.0|       39.5|  18.5|        70.8|
# |25773128767| 2019-01-15 05:17:51|  2019-01-15 05:39:56|        12.63|            1.0|       34.5|  18.0|       79.12|
# |25775053178| 2019-01-22 20:51:41|  2019-01-22 21:14:37|        14.26|            1.0|       38.5|  18.0|        90.3|
# +-----------+--------------------+---------------------+-------------+---------------+-----------+------+------------+
# only showing top 10 rows

# %%
df_jan.orderBy(
    F.col("extra").desc()
).select(
    "trip_id",
    "extra"
).show(1)
# Out:
# +-----------+------+
# |    trip_id| extra|
# +-----------+------+
# |25775127259|535.38|
# +-----------+------+
# only showing top 1 row

# %% [markdown]
# **10)**

# %% [markdown]
# ### Extrem value

# %%
df_jan.select(
    "trip_distance",
    "trip_duration_minutes",
    "fare_amount",
    "extra",
    "tip_amount",
    "total_amount"
).summary(
    "count",
    "min",
    "25%",
    "50%",
    "75%",
    "max"
).show()
# Out:
# +-------+-------------+---------------------+-----------+-------+----------+------------+
# |summary|trip_distance|trip_duration_minutes|fare_amount|  extra|tip_amount|total_amount|
# +-------+-------------+---------------------+-----------+-------+----------+------------+
# |  count|      7696080|              7696080|    7696080|7696080|   7696080|     7696080|
# |    min|          0.0|             -84280.5|     -362.0|  -60.0|     -63.5|      -362.8|
# |    25%|          0.9|                  6.1|        6.0|    0.0|       0.0|         8.3|
# |    50%|         1.54|   10.183333333333334|        9.0|    0.0|       1.4|        11.3|
# |    75%|         2.83|                16.65|       13.5|    0.5|      2.32|        16.6|
# |    max|        831.8|    43648.01666666667|  623259.86| 535.38|    787.25|   623261.66|
# +-------+-------------+---------------------+-----------+-------+----------+------------+

# %% [markdown]
# ### Impossible time of trip

# %%
df_jan.filter(
    F.col("trip_duration_seconds") <= 0
).select(
    "trip_id",
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "trip_distance",
    "trip_duration_minutes"
).show()
# Out:
# +-----------+--------------------+---------------------+-------------+---------------------+
# |    trip_id|tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|trip_duration_minutes|
# +-----------+--------------------+---------------------+-------------+---------------------+
# |25769803804| 2019-01-01 00:32:59|  2019-01-01 00:32:59|          0.0|                  0.0|
# |25769804457| 2019-01-01 00:39:07|  2019-01-01 00:39:07|          0.0|                  0.0|
# |25769807328| 2019-01-01 00:18:46|  2019-01-01 00:18:46|          0.0|                  0.0|
# |25769807437| 2019-01-01 00:54:29|  2019-01-01 00:54:29|          0.0|                  0.0|
# |25769808349| 2019-01-01 00:58:14|  2019-01-01 00:58:14|          0.0|                  0.0|
# |25769810249| 2019-01-01 00:18:15|  2019-01-01 00:18:15|          0.0|                  0.0|
# |25769810250| 2019-01-01 00:18:17|  2019-01-01 00:18:17|          0.0|                  0.0|
# |25769812271| 2019-01-01 00:27:16|  2019-01-01 00:27:16|          0.0|                  0.0|
# |25769812914| 2019-01-01 00:41:47|  2019-01-01 00:41:47|          0.0|                  0.0|
# |25769813332| 2019-01-01 00:26:35|  2019-01-01 00:26:35|          0.0|                  0.0|
# |25769813627| 2019-01-01 00:34:41|  2019-01-01 00:34:41|          0.0|                  0.0|
# |25769813844| 2019-01-01 00:40:16|  2019-01-01 00:40:16|          0.0|                  0.0|
# |25769814720| 2019-01-01 00:32:48|  2019-01-01 00:32:48|          0.0|                  0.0|
# |25769815239| 2019-01-01 00:47:56|  2019-01-01 00:47:56|          0.0|                  0.0|
# |25769816043| 2019-01-01 00:36:54|  2019-01-01 00:36:54|          0.0|                  0.0|
# |25769817033| 2019-01-01 00:43:34|  2019-01-01 00:43:34|          0.0|                  0.0|
# |25769817034| 2019-01-01 00:02:52|  2019-01-01 00:02:52|          0.0|                  0.0|
# |25769817779| 2019-01-01 01:16:15|  2019-01-01 01:16:15|          0.0|                  0.0|
# |25769818642| 2019-01-01 01:39:34|  2019-01-01 01:39:34|          0.0|                  0.0|
# |25769818789| 2019-01-01 01:49:50|  2019-01-01 01:49:50|          0.0|                  0.0|
# +-----------+--------------------+---------------------+-------------+---------------------+
# only showing top 20 rows

# %%
invalid_duration_count = df_jan.filter(
    F.col("trip_duration_seconds") <= 0
).count()

print("Trips with zero or negative duration:", invalid_duration_count)
# Out:
# Trips with zero or negative duration: 6554

# %% [markdown]
# ### Strange distance

# %%
df_jan.filter(
    F.col("trip_distance") <= 0
).select(
    "trip_id",
    "trip_distance",
    "fare_amount",
    "total_amount"
).show(10)
# Out:
# +-----------+-------------+-----------+------------+
# |    trip_id|trip_distance|fare_amount|total_amount|
# +-----------+-------------+-----------+------------+
# |25769803804|          0.0|        6.5|         7.8|
# |25769804235|          0.0|        3.0|         4.3|
# |25769804457|          0.0|        2.5|         3.8|
# |25769804621|          0.0|        3.5|         4.8|
# |25769804723|          0.0|        2.5|        11.8|
# |25769805114|          0.0|        3.5|         4.8|
# |25769805314|          0.0|        3.0|         4.3|
# |25769805411|          0.0|        7.0|        9.95|
# |25769805412|          0.0|        6.5|         7.8|
# |25769805413|          0.0|        8.0|         9.3|
# +-----------+-------------+-----------+------------+
# only showing top 10 rows

# %%
zero_distance_count = df_jan.filter(
    F.col("trip_distance") == 0
).count()

print("Trips with zero distance:", zero_distance_count)
# Out:
# Trips with zero distance: 55060

# %% [markdown]
# ### Extrem amount

# %%
df_jan.orderBy(
    F.col("fare_amount").desc()
).select(
    "trip_id",
    "trip_distance",
    "trip_duration_minutes",
    "fare_amount",
    "extra",
    "tip_amount",
    "total_amount"
).show(10)
# Out:
# +-----------+-------------+---------------------+-----------+------+----------+------------+
# |    trip_id|trip_distance|trip_duration_minutes|fare_amount| extra|tip_amount|total_amount|
# +-----------+-------------+---------------------+-----------+------+----------+------------+
# |25772303431|          2.4|                 19.9|  623259.86|   1.0|       0.0|   623261.66|
# |25775127259|          0.0|                  0.0|  355676.98|535.38|       0.0|   356214.78|
# |25771963747|          0.0|                  0.0|    36090.3|   0.0|       0.0|     36090.3|
# |25771696557|          0.0|                  0.0|   34674.65|   0.0|       0.0|    34674.65|
# |25771453227|          0.0|                  0.0|   33023.53|   0.0|       0.0|    33023.53|
# |25770455409|          0.0|                  0.0|   31107.91|   0.0|       0.0|    31107.91|
# |25772248553|          0.0|                  0.0|   30444.52|   0.0|       0.0|    30444.52|
# |25770541107|          0.0|                  0.0|   30130.71|   0.0|       0.0|    30130.71|
# |25771223461|          0.0|                  0.0|   25628.96|   0.0|       0.0|    25628.96|
# |25770104888|          0.0|                  0.0|   25356.38|   0.0|       0.0|    25356.38|
# +-----------+-------------+---------------------+-----------+------+----------+------------+
# only showing top 10 rows

# %%
df_jan.orderBy(
    F.col("total_amount").desc()
).select(
    "trip_id",
    "trip_distance",
    "fare_amount",
    "extra",
    "tip_amount",
    "total_amount"
).show(10)
# Out:
# +-----------+-------------+-----------+------+----------+------------+
# |    trip_id|trip_distance|fare_amount| extra|tip_amount|total_amount|
# +-----------+-------------+-----------+------+----------+------------+
# |25772303431|          2.4|  623259.86|   1.0|       0.0|   623261.66|
# |25775127259|          0.0|  355676.98|535.38|       0.0|   356214.78|
# |25771963747|          0.0|    36090.3|   0.0|       0.0|     36090.3|
# |25771696557|          0.0|   34674.65|   0.0|       0.0|    34674.65|
# |25771453227|          0.0|   33023.53|   0.0|       0.0|    33023.53|
# |25770455409|          0.0|   31107.91|   0.0|       0.0|    31107.91|
# |25772248553|          0.0|   30444.52|   0.0|       0.0|    30444.52|
# |25770541107|          0.0|   30130.71|   0.0|       0.0|    30130.71|
# |25771223461|          0.0|   25628.96|   0.0|       0.0|    25628.96|
# |25770104888|          0.0|   25356.38|   0.0|       0.0|    25356.38|
# +-----------+-------------+-----------+------+----------+------------+
# only showing top 10 rows

# %%
df_jan.filter(
    (F.col("fare_amount") < 0) |
    (F.col("total_amount") < 0)
).select(
    "trip_id",
    "trip_distance",
    "fare_amount",
    "tip_amount",
    "total_amount"
).show(20)
# Out:
# +-----------+-------------+-----------+----------+------------+
# |    trip_id|trip_distance|fare_amount|tip_amount|total_amount|
# +-----------+-------------+-----------+----------+------------+
# |25769804439|          0.1|       -2.5|       0.0|        -3.8|
# |25769806178|         4.13|      -19.0|       0.0|       -20.3|
# |25769806317|         1.35|       -8.5|       0.0|        -9.8|
# |25769806320|          0.0|       -2.5|       0.0|        -3.8|
# |25769806323|         0.16|       -3.0|       0.0|        -4.3|
# |25769807004|         0.42|       -4.5|       0.0|        -5.8|
# |25769807558|         0.47|      -24.0|       0.0|       -24.8|
# |25769807703|          0.7|      -52.0|       0.0|       -52.8|
# |25769808037|          0.4|       -4.0|       0.0|        -5.3|
# |25769809076|        15.13|      -43.5|       0.0|       -44.8|
# |25769809557|          0.0|       -3.5|       0.0|        -4.8|
# |25769810853|         0.13|       -3.5|       0.0|        -4.8|
# |25769813140|         0.36|       -3.5|       0.0|        -4.8|
# |25769816234|          0.1|       -3.0|       0.0|        -4.3|
# |25769820464|         0.05|       -3.0|       0.0|        -4.3|
# |25769822604|         0.01|       -2.5|       0.0|        -3.8|
# |25769823521|         8.83|      -27.0|       0.0|       -28.3|
# |25769823628|         0.19|       -3.5|       0.0|        -4.8|
# |25769823860|         0.23|       -3.5|       0.0|        -4.8|
# |25769823993|         0.01|       -2.5|       0.0|        -3.8|
# +-----------+-------------+-----------+----------+------------+
# only showing top 20 rows

# %% [markdown]
# ### Part 2
#
# - 1) Using the code for loading the first dataset as an example, load in the taxi zone lookup and answer the following questions
# - 2) which borough had most pickups? dropoffs?
# - 3) what are the busy/slow times by borough
# - 4) what are the busiest days of the week by borough?
# - 5) what is the average trip distance by borough?
# - 6) what is the average trip fare by borough?
# - 7) highest/lowest faire amounts for a trip, what burough is associated with the each
# - 8) load the dataset from the most recently available january, is there a change to any of the average metrics.

# %% [markdown]
# **1)**

# %%
zone_url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"

response = requests.get(zone_url)

zone_file = "taxi_zone_lookup.csv"

if response.status_code == 200:
    with open(zone_file, "wb") as f:
        f.write(response.content)

print("Status:", response.status_code)
# Out:
# Status: 200

# %%
df_zones = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(zone_file)
)
df_zones.show(10)
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 10 rows

# %%
df_zones.printSchema()
# Out:
# root
#  |-- LocationID: integer (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- Zone: string (nullable = true)
#  |-- service_zone: string (nullable = true)

# %%
pickup_zones = df_zones.select(
    F.col("LocationID").alias("PULocationID"),
    F.col("Borough").alias("pickup_borough"),
    F.col("Zone").alias("pickup_zone")
)
pickup_zones.show(5)
# Out:
# +------------+--------------+--------------------+
# |PULocationID|pickup_borough|         pickup_zone|
# +------------+--------------+--------------------+
# |           1|           EWR|      Newark Airport|
# |           2|        Queens|         Jamaica Bay|
# |           3|         Bronx|Allerton/Pelham G...|
# |           4|     Manhattan|       Alphabet City|
# |           5| Staten Island|       Arden Heights|
# +------------+--------------+--------------------+
# only showing top 5 rows

# %%
dropoff_zones = df_zones.select(
    F.col("LocationID").alias("DOLocationID"),
    F.col("Borough").alias("dropoff_borough"),
    F.col("Zone").alias("dropoff_zone")
)
df_enriched = (
    df_jan
    .join(
        pickup_zones,
        on="PULocationID",
        how="left"
    )
    .join(
        dropoff_zones,
        on="DOLocationID",
        how="left"
    )
)
df_enriched.select(
    "PULocationID",
    "pickup_borough",
    "pickup_zone",
    "DOLocationID",
    "dropoff_borough",
    "dropoff_zone"
).show(10)
# Out:
# +------------+--------------+--------------------+------------+---------------+--------------------+
# |PULocationID|pickup_borough|         pickup_zone|DOLocationID|dropoff_borough|        dropoff_zone|
# +------------+--------------+--------------------+------------+---------------+--------------------+
# |         151|     Manhattan|    Manhattan Valley|         239|      Manhattan|Upper West Side S...|
# |         239|     Manhattan|Upper West Side S...|         246|      Manhattan|West Chelsea/Huds...|
# |         163|     Manhattan|       Midtown North|         229|      Manhattan|Sutton Place/Turt...|
# |         229|     Manhattan|Sutton Place/Turt...|           7|         Queens|             Astoria|
# |         141|     Manhattan|     Lenox Hill West|         234|      Manhattan|            Union Sq|
# |         246|     Manhattan|West Chelsea/Huds...|         162|      Manhattan|        Midtown East|
# |         238|     Manhattan|Upper West Side N...|         151|      Manhattan|    Manhattan Valley|
# |         163|     Manhattan|       Midtown North|          25|       Brooklyn|         Boerum Hill|
# |         224|     Manhattan|Stuy Town/Peter C...|          25|       Brooklyn|         Boerum Hill|
# |         141|     Manhattan|     Lenox Hill West|         234|      Manhattan|            Union Sq|
# +------------+--------------+--------------------+------------+---------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# **2)**

# %%
pickups_by_borough = (
    df_enriched
    .groupBy("pickup_borough")
    .count()
    .orderBy(F.col("count").desc())
)
pickups_by_borough.show(1)
# Out:
# +--------------+-------+
# |pickup_borough|  count|
# +--------------+-------+
# |     Manhattan|6950511|
# +--------------+-------+
# only showing top 1 row

# %%
dropoffs_by_borough = (
    df_enriched
    .groupBy("dropoff_borough")
    .count()
    .orderBy(F.col("count").desc())
)
dropoffs_by_borough.show(1)
# Out:
# +---------------+-------+
# |dropoff_borough|  count|
# +---------------+-------+
# |      Manhattan|6816936|
# +---------------+-------+
# only showing top 1 row

# %% [markdown]
# **3)**

# %%
borough_hour_counts = (
    df_enriched
    .groupBy(
        "pickup_borough",
        "pickup_hour"
    )
    .count()
)
borough_hour_counts.orderBy(
    "pickup_borough",
    "pickup_hour"
).show(50)
# Out:
# +--------------+-----------+-----+
# |pickup_borough|pickup_hour|count|
# +--------------+-----------+-----+
# |         Bronx|          0|  324|
# |         Bronx|          1|  254|
# |         Bronx|          2|  225|
# |         Bronx|          3|  225|
# |         Bronx|          4|  403|
# |         Bronx|          5|  736|
# |         Bronx|          6| 1301|
# |         Bronx|          7| 1803|
# |         Bronx|          8| 1445|
# |         Bronx|          9| 1158|
# |         Bronx|         10| 1079|
# |         Bronx|         11|  885|
# |         Bronx|         12|  956|
# |         Bronx|         13|  917|
# |         Bronx|         14| 1014|
# |         Bronx|         15|  897|
# |         Bronx|         16|  756|
# |         Bronx|         17|  812|
# |         Bronx|         18|  741|
# |         Bronx|         19|  517|
# |         Bronx|         20|  440|
# |         Bronx|         21|  408|
# |         Bronx|         22|  353|
# |         Bronx|         23|  407|
# |      Brooklyn|          0| 3809|
# |      Brooklyn|          1| 3350|
# |      Brooklyn|          2| 2643|
# |      Brooklyn|          3| 1919|
# |      Brooklyn|          4| 1960|
# |      Brooklyn|          5| 2118|
# |      Brooklyn|          6| 4456|
# |      Brooklyn|          7| 6318|
# |      Brooklyn|          8| 6935|
# |      Brooklyn|          9| 4691|
# |      Brooklyn|         10| 3697|
# |      Brooklyn|         11| 3329|
# |      Brooklyn|         12| 3767|
# |      Brooklyn|         13| 3950|
# |      Brooklyn|         14| 3925|
# |      Brooklyn|         15| 3829|
# |      Brooklyn|         16| 3399|
# |      Brooklyn|         17| 3803|
# |      Brooklyn|         18| 4289|
# |      Brooklyn|         19| 3804|
# |      Brooklyn|         20| 3420|
# |      Brooklyn|         21| 3815|
# |      Brooklyn|         22| 4330|
# |      Brooklyn|         23| 4340|
# |           EWR|          0|    2|
# |           EWR|          1|    1|
# +--------------+-----------+-----+
# only showing top 50 rows

# %%
from pyspark.sql.window import Window

borough_window_desc = (
    Window
    .partitionBy("pickup_borough")
    .orderBy(F.col("count").desc())
)
busiest_hour_by_borough = (
    borough_hour_counts
    .withColumn(
        "rank",
        F.row_number().over(borough_window_desc)
    )
    .filter(F.col("rank") == 1)
    .drop("rank")
)
busiest_hour_by_borough.orderBy(
    "pickup_borough"
).show()
# Out:
# +--------------+-----------+------+
# |pickup_borough|pickup_hour| count|
# +--------------+-----------+------+
# |         Bronx|          7|  1803|
# |      Brooklyn|          8|  6935|
# |           EWR|         15|    54|
# |     Manhattan|         18|471524|
# |           N/A|         19|   214|
# |        Queens|         16| 29880|
# | Staten Island|          8|    36|
# |       Unknown|         18| 10751|
# +--------------+-----------+------+

# %%
borough_window_asc = (
    Window
    .partitionBy("pickup_borough")
    .orderBy(F.col("count").asc())
)
slowest_hour_by_borough = (
    borough_hour_counts
    .withColumn(
        "rank",
        F.row_number().over(borough_window_asc)
    )
    .filter(F.col("rank") == 1)
    .drop("rank")
)
slowest_hour_by_borough.orderBy(
    "pickup_borough"
).show()
# Out:
# +--------------+-----------+-----+
# |pickup_borough|pickup_hour|count|
# +--------------+-----------+-----+
# |         Bronx|          3|  225|
# |      Brooklyn|          3| 1919|
# |           EWR|         23|    1|
# |     Manhattan|          4|53446|
# |           N/A|          6|   88|
# |        Queens|          3| 3084|
# | Staten Island|          1|    3|
# |       Unknown|          4| 1465|
# +--------------+-----------+-----+

# %% [markdown]
# **4)**

# %%
df_enriched = df_enriched.withColumn(
    "pickup_day_name",
    F.date_format("tpep_pickup_datetime", "EEEE")
)
df_enriched.select(
    "tpep_pickup_datetime",
    "pickup_borough",
    "pickup_day_name"
).show(10)
# Out:
# +--------------------+--------------+---------------+
# |tpep_pickup_datetime|pickup_borough|pickup_day_name|
# +--------------------+--------------+---------------+
# | 2019-01-01 00:46:40|     Manhattan|        Tuesday|
# | 2019-01-01 00:59:47|     Manhattan|        Tuesday|
# | 2019-01-01 00:21:28|     Manhattan|        Tuesday|
# | 2019-01-01 00:32:01|     Manhattan|        Tuesday|
# | 2019-01-01 00:57:32|     Manhattan|        Tuesday|
# | 2019-01-01 00:24:04|     Manhattan|        Tuesday|
# | 2019-01-01 00:21:59|     Manhattan|        Tuesday|
# | 2019-01-01 00:45:21|     Manhattan|        Tuesday|
# | 2019-01-01 00:43:19|     Manhattan|        Tuesday|
# | 2019-01-01 00:58:24|     Manhattan|        Tuesday|
# +--------------------+--------------+---------------+
# only showing top 10 rows

# %%
borough_daily_counts = (
    df_enriched
    .groupBy(
        "pickup_borough",
        "pickup_date"
    )
    .count()
)
borough_daily_counts = borough_daily_counts.withColumn(
    "day_name",
    F.date_format("pickup_date", "EEEE")
)
borough_weekday_avg = (
    borough_daily_counts
    .groupBy(
        "pickup_borough",
        "day_name"
    )
    .agg(
        F.avg("count").alias("avg_trips")
    )
)
borough_weekday_avg.orderBy(
    "pickup_borough",
    F.col("avg_trips").desc()
).show(50)
# Out:
# +--------------+---------+---------+
# |pickup_borough| day_name|avg_trips|
# +--------------+---------+---------+
# |         Bronx|   Friday|    666.5|
# |         Bronx| Thursday|    624.2|
# |         Bronx|  Tuesday|    611.8|
# |         Bronx|Wednesday|    599.6|
# |         Bronx|   Monday|    543.0|
# |         Bronx|   Sunday|    528.0|
# |         Bronx| Saturday|    482.0|
# |      Brooklyn|   Friday|   3273.0|
# |      Brooklyn|  Tuesday|   3155.8|
# |      Brooklyn| Thursday|   3142.8|
# |      Brooklyn|Wednesday|   3020.2|
# |      Brooklyn| Saturday|   2901.0|
# |      Brooklyn|   Sunday|  2774.75|
# |      Brooklyn|   Monday|  2376.75|
# |           EWR|   Friday|     18.5|
# |           EWR|   Sunday|     17.0|
# |           EWR|Wednesday|     16.6|
# |           EWR|  Tuesday|     15.4|
# |           EWR| Saturday|    13.75|
# |           EWR| Thursday|     11.6|
# |           EWR|   Monday|     7.75|
# |     Manhattan|   Friday| 246224.0|
# |     Manhattan| Thursday| 245903.2|
# |     Manhattan| Saturday| 231874.5|
# |     Manhattan|Wednesday| 228952.8|
# |     Manhattan|  Tuesday| 217238.8|
# |     Manhattan|   Monday|201858.25|
# |     Manhattan|   Sunday| 192552.5|
# |           N/A|  Tuesday|    140.6|
# |           N/A|   Monday|    129.0|
# |           N/A|Wednesday|    127.0|
# |           N/A| Thursday|    126.6|
# |           N/A| Saturday|   122.75|
# |           N/A|   Sunday|   117.25|
# |           N/A|   Friday|   110.75|
# |        Queens|   Monday|  16662.0|
# |        Queens|   Friday|  16038.0|
# |        Queens| Thursday|  15792.2|
# |        Queens|  Tuesday|  15736.8|
# |        Queens|Wednesday|  15163.4|
# |        Queens|   Sunday| 14798.25|
# |        Queens| Saturday|  11914.5|
# | Staten Island|   Friday|     16.0|
# | Staten Island| Thursday|     12.4|
# | Staten Island|  Tuesday|     11.4|
# | Staten Island|   Sunday|    10.75|
# | Staten Island|   Monday|    10.75|
# | Staten Island|Wednesday|     10.4|
# | Staten Island| Saturday|     10.0|
# |       Unknown| Thursday|   5785.4|
# +--------------+---------+---------+
# only showing top 50 rows

# %%
weekday_window = (
    Window
    .partitionBy("pickup_borough")
    .orderBy(F.col("avg_trips").desc())
)
busiest_weekday_by_borough = (
    borough_weekday_avg
    .withColumn(
        "rank",
        F.row_number().over(weekday_window)
    )
    .filter(F.col("rank") == 1)
    .drop("rank")
)
busiest_weekday_by_borough.orderBy(
    "pickup_borough"
).show()
# Out:
# +--------------+--------+---------+
# |pickup_borough|day_name|avg_trips|
# +--------------+--------+---------+
# |         Bronx|  Friday|    666.5|
# |      Brooklyn|  Friday|   3273.0|
# |           EWR|  Friday|     18.5|
# |     Manhattan|  Friday| 246224.0|
# |           N/A| Tuesday|    140.6|
# |        Queens|  Monday|  16662.0|
# | Staten Island|  Friday|     16.0|
# |       Unknown|Thursday|   5785.4|
# +--------------+--------+---------+

# %% [markdown]
# **5)**

# %%
avg_distance_by_borough = (
    df_enriched
    .groupBy("pickup_borough")
    .agg(
        F.avg("trip_distance").alias("avg_trip_distance")
    )
    .orderBy(
        F.col("avg_trip_distance").desc()
    )
)
avg_distance_by_borough.show()
# Out:
# +--------------+------------------+
# |pickup_borough| avg_trip_distance|
# +--------------+------------------+
# | Staten Island|12.503601108033246|
# |        Queens|11.283685060696447|
# |         Bronx| 7.234111098803697|
# |      Brooklyn|   4.7876346086881|
# |           N/A| 3.193850899742941|
# |           EWR| 2.641098654708519|
# |       Unknown| 2.415580669182199|
# |     Manhattan|2.2286369894240687|
# +--------------+------------------+

# %% [markdown]
# **6)**

# %%
avg_fare_by_borough = (
    df_enriched
    .groupBy("pickup_borough")
    .agg(
        F.avg("fare_amount").alias("avg_fare")
    )
    .orderBy(
        F.col("avg_fare").desc()
    )
)

avg_fare_by_borough.show()
# Out:
# +--------------+------------------+
# |pickup_borough|          avg_fare|
# +--------------+------------------+
# |           EWR| 76.24024663677126|
# |           N/A|  59.5731593830335|
# | Staten Island|45.289861495844896|
# |        Queens|35.144710419789384|
# |         Bronx|26.270240917147586|
# |      Brooklyn| 18.64909843736217|
# |       Unknown| 14.94432265169866|
# |     Manhattan|  10.7923875395659|
# +--------------+------------------+

# %% [markdown]
# **7)**

# %%
df_enriched.orderBy(
    F.col("fare_amount").desc()
).select(
    "trip_id",
    "pickup_borough",
    "pickup_zone",
    "trip_distance",
    "fare_amount"
).show(5)
# Out:
# +-----------+--------------+--------------------+-------------+-----------+
# |    trip_id|pickup_borough|         pickup_zone|trip_distance|fare_amount|
# +-----------+--------------+--------------------+-------------+-----------+
# |25772303431|     Manhattan|Upper East Side S...|          2.4|  623259.86|
# |25775127259|     Manhattan|        Bloomingdale|          0.0|  355676.98|
# |25771963747|       Unknown|                 N/A|          0.0|    36090.3|
# |25771696557|       Unknown|                 N/A|          0.0|   34674.65|
# |25771453227|       Unknown|                 N/A|          0.0|   33023.53|
# +-----------+--------------+--------------------+-------------+-----------+
# only showing top 5 rows

# %%
df_enriched.orderBy(
    F.col("fare_amount").asc()
).select(
    "trip_id",
    "pickup_borough",
    "pickup_zone",
    "trip_distance",
    "fare_amount"
).show(5)
# Out:
# +-----------+--------------+--------------------+-------------+-----------+
# |    trip_id|pickup_borough|         pickup_zone|trip_distance|fare_amount|
# +-----------+--------------+--------------------+-------------+-----------+
# |25774694425|        Queens|         JFK Airport|          0.0|     -362.0|
# |25776111976|           N/A|      Outside of NYC|          0.0|     -320.0|
# |25769860870|         Bronx|University Height...|          0.0|     -300.0|
# |25777031630|           N/A|      Outside of NYC|          0.0|     -300.0|
# |25771008664|        Queens|         JFK Airport|         0.75|     -284.0|
# +-----------+--------------+--------------------+-------------+-----------+
# only showing top 5 rows

# %% [markdown]
# **8)**

# %%
download_url_2025 = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet"

response = requests.get(download_url_2025)

jan_2025_trip_data = "yellow_tripdata_2025-01.parquet"

if response.status_code == 200:
    with open(jan_2025_trip_data, "wb") as f:
        f.write(response.content)

print("Status:", response.status_code)
# Out:
# Status: 200

# %%
df_2025 = spark.read.parquet(jan_2025_trip_data)
df_2025.printSchema()
print("Number of rows:", df_2025.count())
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# Number of rows: 3475226

# %%
df_2025 = df_2025.withColumn(
    "pickup_date",
    F.to_date("tpep_pickup_datetime")
)

df_2025_jan = df_2025.filter(
    (F.col("pickup_date") >= "2025-01-01") &
    (F.col("pickup_date") <= "2025-01-31")
)
comparison_2019 = df_jan.select(
    F.lit("2019").alias("year"),
    F.avg("passenger_count").alias("avg_passengers"),
    F.avg("trip_distance").alias("avg_distance"),
    F.avg("fare_amount").alias("avg_fare"),
    F.avg("tip_amount").alias("avg_tip"),
    F.avg("total_amount").alias("avg_total")
)

comparison_2025 = df_2025_jan.select(
    F.lit("2025").alias("year"),
    F.avg("passenger_count").alias("avg_passengers"),
    F.avg("trip_distance").alias("avg_distance"),
    F.avg("fare_amount").alias("avg_fare"),
    F.avg("tip_amount").alias("avg_tip"),
    F.avg("total_amount").alias("avg_total")
)

comparison = comparison_2019.unionByName(comparison_2025)

comparison.show()
# Out:
# +----+------------------+------------------+------------------+------------------+------------------+
# |year|avg_passengers    |avg_distance      |avg_fare          |avg_tip           |avg_total         |
# +----+------------------+------------------+------------------+------------------+------------------+
# |2019|1.5670089553079738|2.830113865760418 |12.52951516096942 |1.8208502016665093|15.810505065320218|
# |2025|1.297854725039224 |5.8551408435296795|17.081793465938812|2.9598042014218784|25.611277927849706|
# +----+------------------+------------------+------------------+------------------+------------------+

# %% [markdown]
# ### Part 3
#
# - choose 3 questions from above and re-answer them using the language you did not use for the main notebook . (i.e - if you completed the exercise in python, redo 3 questions in pure sql) . at least one of the questions to be redone must involve a join

# %%
df_jan.createOrReplaceTempView("trips")
df_zones.createOrReplaceTempView("zones")

# %% [markdown]
# ## Q1 Average passenger count

# %%
spark.sql("""
    SELECT
        AVG(passenger_count) AS avg_passenger_count
    FROM trips
""").show()
# Out:
# +-------------------+
# |avg_passenger_count|
# +-------------------+
# | 1.5670089553079738|
# +-------------------+

# %% [markdown]
# ## Q2 Busiest day

# %%
spark.sql("""
    SELECT
        pickup_date,
        COUNT(*) AS trip_count
    FROM trips
    GROUP BY pickup_date
    ORDER BY trip_count DESC
    LIMIT 1
""").show()
# Out:
# +-----------+----------+
# |pickup_date|trip_count|
# +-----------+----------+
# | 2019-01-25|    292499|
# +-----------+----------+

# %% [markdown]
# ## Q3 Borough with most pickups

# %%
spark.sql("""
    SELECT
        z.Borough AS pickup_borough,
        COUNT(*) AS pickup_count
    FROM trips t
    LEFT JOIN zones z
        ON t.PULocationID = z.LocationID
    GROUP BY z.Borough
    ORDER BY pickup_count DESC
    LIMIT 1
""").show()
# Out:
# +--------------+------------+
# |pickup_borough|pickup_count|
# +--------------+------------+
# |     Manhattan|     6950511|
# +--------------+------------+

# %% [markdown]
# # Where to go from here
#
# - Continue building the dataset by loading in more data, start by completing the data for 2019 and calculating the busiest season (fall, winter, spring, summer)
# - As of spark v4 dataframes have native visualization support. Choose at least 3 questions from above and provide visualizations.
# - Explore a dataset/datasets of your choosing
